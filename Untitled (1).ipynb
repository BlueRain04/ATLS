# %%
import sys, os
from types import SimpleNamespace

sys.path.append(os.getcwd())

from resco_benchmark.main import run_trial

args = SimpleNamespace(
    agent='MA2C',
    map='ingolstadt7',
    eps=2,
    trials=1,
    procs=1,
    pwd=os.path.abspath(''), 
    log_dir=os.path.join(os.getcwd(), 'results'),
    gui=False,
    libsumo=False,
    tr=0,
    save_freq=100,
    load=False
)

run_trial(args, args.tr)
# Out:
# ingolstadt7 C:\Users\nahed\RESCO\environments/ingolstadt7/ingolstadt7.sumocfg ma2c wait
# [DEBUG]: ['C:\\Program Files (x86)\\Eclipse\\Sumo\\bin\\sumo.exe', '-c', 'C:\\Users\\nahed\\RESCO\\environments/ingolstadt7/ingolstadt7.sumocfg', '--no-warnings', 'True']
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52088 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52090 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52092 (TraCI server already finished). Retrying with different port.
# ...

# %%
import resco_benchmark.config.agent_config as ac
print(ac.agent_configs.keys())
# Out:
# dict_keys(['MAXWAVEVAL', 'MAXPRESSUREVAL', 'MPLightVAL', 'FMA2CVAL', 'STOCHASTIC', 'MAXWAVE', 'MAXPRESSURE', 'IDQN', 'IPPO', 'MPLight', 'FMA2C', 'MPLightFULL', 'FMA2CFULL'])
